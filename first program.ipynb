# %% [markdown]
# <a href="https://colab.research.google.com/github/HatemSAHamatta/GithubTest/blob/main/first%20program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
print("this is the value of a: ", a)
# Out:
# this is the value of a:  20
